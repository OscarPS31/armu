# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
# menu_semanal from B
# recipes_df
# ingredientes_precios.csv from A
# budget from D

# %%
recipes_df = pd.read_csv('raw_data/recipes_clean.csv')

# %%
df_ingredientes = pd.read_csv('raw_data/ingredient_prices.csv')

# %%
recipes_df
# Out:
#             id                                               name  \
# 0        71247                            Cherry Streusel Cobbler
# 1        76133                    Reuben and Swiss Casserole Bake
# 2       503816                                   Yam-Pecan Recipe
# 3       418749                        Tropical  Orange Layer Cake
# 4       392934  Safe to Eat Raw Chocolate Chip Oreo Cookie &qu...
# ...        ...                                                ...
# 500431  173790                              Sausage Meatloaf OAMC
# 500432  301838       Potato Salad With Olives Capers and Parmesan
# 500433  130682                        Chocolate Banana Pound Cake
# 500434  353659              Cheesy Ground Beef and Rice Casserole
# 500435  510848            Chicken and Dumplings &ndash; Crock Pot
#
#                                               description  \
# 0       I haven't made this in years, so I'm just gues...
# ...

# %%
ingredientes_ #Creo que Jose necesita standarizar las unidades
# Out:
#        ingredient    profeco_category   price          unit  \
# 0            salt  Sal Molida de Mesa   28.00            kg
# 1           sugar              Azúcar   28.00            kg
# 2          butter         Mantequilla   29.99             g
# 3             egg               Huevo   42.00  presentacion
# 4          garlic                 Ajo   80.00            kg
# 5           onion             Cebolla   25.00        manojo
# 6           flour     Harina de Trigo   19.00            kg
# 7       olive oil     Aceite de Oliva  219.00            ml
# 8            milk  Leche Pasteurizada   33.50         litro
# 9         vanilla            Vainilla   27.90            ml
# 10         pepper            Pimienta   86.50             g
# 11    lemon juice               Limón   32.00            kg
# 12  baking powder     Polvo P/hornear   19.90             g
# 13         carrot           Zanahoria   16.90            kg
# 14       cinnamon              Canela   49.90             g
# ...

# %%
menu_sample = {
    "lunes": [503816],
    "martes": [71247],
    "miercoles": [418749],
    "jueves": [130682],
    "viernes": [76133],
    "sabado": [392934],
    "domingo": [173790]
}
