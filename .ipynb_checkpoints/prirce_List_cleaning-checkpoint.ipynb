# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('raw_data/recipes_ingredients.csv')
df_price_ = pd.read_csv('raw_data/07-2026_Q2.csv')

# %%
df.shape,df_price.shape
# Out:
# ((500471, 9), (744623, 15))

# %%
df.head()
# Out:
#        id                                               name  \
# 0   71247                            Cherry Streusel Cobbler
# 1   76133                    Reuben and Swiss Casserole Bake
# 2  503816                                   Yam-Pecan Recipe
# 3  418749                        Tropical  Orange Layer Cake
# 4  392934  Safe to Eat Raw Chocolate Chip Oreo Cookie &qu...
#
#                                          description  \
# 0  I haven't made this in years, so I'm just gues...
# 1  I think this is even better than a reuben sand...
# 2  A lady I work with heard me taking about ZWT a...
# 3  An easy and delicious cake.  Great for a  summ...
# 4  I was searching the web for something like thi...
#
#                                          ingredients  \
# 0  ["cherry pie filling", "condensed milk", "melt...
# 1  ["corned beef chopped", "sauerkraut cold water...
# 2  ["unsalted butter", "vegetable oil", "all - pu...
# 3  ["orange cake mix", "instant vanilla pudding",...
# ...

# %%
df_price.head()
# Out:
#    producto                presentacion marca           categoria  \
# 0    Acelga                      Manojo   S/M  Hortalizas Frescas
# 1  Aguacate          1 Kg. Granel. Hass   S/M      Frutas Frescas
# 2       Ajo  1 Kg. Granel. o Ajo Morado   S/M  Hortalizas Frescas
# 3      Apio                1 Kg. Granel   S/M  Hortalizas Frescas
# 4   Betabel                1 Kg. Granel   S/M  Hortalizas Frescas
#
#              catalogo  precio fecha_registro   cadena_comercial  \
# 0  Frutas y Legumbres    20.0     2026/07/16  Central de Abasto
# 1  Frutas y Legumbres    49.0     2026/07/16  Central de Abasto
# 2  Frutas y Legumbres   140.0     2026/07/16  Central de Abasto
# 3  Frutas y Legumbres    35.0     2026/07/16  Central de Abasto
# 4  Frutas y Legumbres    35.0     2026/07/16  Central de Abasto
#
#                 giro   nombre_comercial  \
# 0  Central de Abasto  Central de Abasto
# 1  Central de Abasto  Central de Abasto
# 2  Central de Abasto  Central de Abasto
# ...

# %%
df_price
# Out:
#         producto                     presentacion  marca           categoria  \
# 0         Acelga                           Manojo    S/M  Hortalizas Frescas
# 1       Aguacate               1 Kg. Granel. Hass    S/M      Frutas Frescas
# 2            Ajo       1 Kg. Granel. o Ajo Morado    S/M  Hortalizas Frescas
# 3           Apio                     1 Kg. Granel    S/M  Hortalizas Frescas
# 4        Betabel                     1 Kg. Granel    S/M  Hortalizas Frescas
# ...          ...                              ...    ...                 ...
# 744618     Tenis    Choclo. 155741. Blanco No. 23  Audaz    Material Escolar
# 744619     Tenis  Choclo. 4211601. Blanco. No. 22  Flexi    Material Escolar
# 744620     Tenis     Choclo. 5002. Blanco. No. 22  Pirma    Material Escolar
# 744621     Tenis     Choclo. 5002. Blanco. No. 24  Pirma    Material Escolar
# 744622     Tenis     Choclo. 5002. Blanco. No. 26  Pirma    Material Escolar
#
# ...

# %%
df_price.iloc[976,1]
# Out:
# '1 Kg. Granel. Amarilla'

# %%
FOOD_CATEGORIES = [
    "Hortalizas Frescas",
    "Frutas Frescas",
    "Frutas y Legumbres Procesadas",
    "Legumbres Secas",
    "Condimentos",
    "Carnes Frías Secas y Embutidos",
    "Carne y Vísceras de Res",
    "Carne y Vísceras de Cerdo",
    "Carne de Ave",
    "Pescados y Mariscos",
    "Pescados y Mariscos en Conserva",
    "Huevo",
    "Derivados de Leche",
    "Leche Procesada",
    "Leche Fresca",
    "Galletas Pastas y Harinas de Trigo",
    "Arroz y Cereales Preparados",
    "Tortillas y Derivados del Maíz",
    "Pan",
    "Aceites y Grasas Veg. Comestibles",
    "Grasas Animales Comestibles",
    "Azúcar",
    "Café",
    "Té",
    "Vinos y Licores",
]

# %%
#Cambiar la lista de precio a incluir solo comida
df_price_food = df_price[df_price["categoria"].isin(FOOD_CATEGORIES)].copy()
df_price_food.shape
# Out:
# (287484, 15)
